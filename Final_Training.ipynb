# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np # to handle matrices
import cv2 # to read files
from glob import glob # to extract images
from sklearn.model_selection import train_test_split # to split dataset (80, 10, 10)
import tensorflow as tf # to handle tensors
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau
    # to save model weights, to save validation and training metrices, reduces learning rate
from tensorflow.keras.optimizers import Adam # type of optimiser
from tensorflow.keras.metrics import Recall, Precision # methods of performance assessment
from UNET_Lung_Segmentation_Model import FullUNET # imports the UNET architecture made beforehand
from UNET_Functions_IoU_DiceCoef_DiceLoss import DiceLoss, DiceCoef, IoU # imports the loss calculation functions

# %%
"""Global Parameters/Variables"""
H = 512
W = 512

# %% [markdown]
# ## Dataset Management

# %%
def CreateDir(path):
    """Creates a Directory"""
    if not os.path.exists(path):
        os.makedirs(path) # creates directory if none exist

# %%
"""Setting-up Training/Validation/Testing Split"""
def LoadData(path, split=0.1): # training=80%, validation=10% and testing=10% 
    #loads imgs/masks sequentially
    orgImages = sorted(glob(os.path.join(path, "orgImgs", "*.png")))
    masks = sorted(glob(os.path.join(path, "maskImgs", "*.png")))
    
    splitSize = int(len(orgImages) * split) # calculates the number of items in dataset divided by 0.1
    
    print(len(orgImages))
    
    xTrain, xValid = train_test_split(orgImages, test_size=splitSize, random_state=74)
    yTrain, yValid = train_test_split(masks, test_size=splitSize, random_state=74)
        # function from sklearn, splits imgs/masks into train and validation sets
        # train=90%, validation=10%
        
    xTrain, xTest = train_test_split(xTrain, test_size=splitSize, random_state=74)
    yTrain, yTest = train_test_split(yTrain, test_size=splitSize, random_state=74)
        # train=80%, validation=10%, test=10%
    
    return (xTrain, yTrain), (xValid, yValid), (xTest, yTest)

"""Alterations to Images and Masks"""
def ReadImg(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR) # reads img as a 3-channel img
    x = cv2.resize(x, (W, H)) # makes images 512 by 512
        # x is now a val between 0 and 1
    x = x/255.0 # normalise: dividing by max pixel val
    x = x.astype(np.float32) # converts x to a 32-bit floating point num
    return x

def ReadMask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    x = x/255.0 
    x = x > 0.5 # converts x val into binary scale
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1) # creates 1-channel numpy matrix/img
    return x

"""Converting All Data to Tensors"""
def TfParse(x, y):
    def Parse(x, y):
        # decodes the strings
        x = x.decode()
        y = y.decode()
        
        # gets numpy arrays
        x = ReadImg(x)
        y = ReadMask(y)
        return x, y 
   
    # converts x and y to tensors
    x, y = tf.numpy_function(Parse, [x, y], [tf.float32, tf.float32]) 
        # allows tenserflow function to use cv2 and np attributes 
        # (function used, input, input's datatype)
    x.set_shape([W, H, 3])
    y.set_shape([W, H, 1])
    return x, y

"""Pipeline for Training and Validation""" 
def TfDataset(X, Y, batch=8): 
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.shuffle(buffer_size=200) # shuffles data to terminate patterns
    dataset = dataset.map(TfParse) # parses parts into tensors
    dataset = dataset.batch(batch) # creates batch of data
    dataset = dataset.prefetch(4) # fetches data into RAM - optimises
    return dataset

# %%
if __name__ == "__main__":
    """Seed Declaration"""
    np.random.seed(74)
    tf.random.set_seed(74)
    
    """Storage of Files used for Training"""
    CreateDir("TrainingFilesForUnet")
    
    """Hyperparameters"""
    batchSize = 2 # batch size before OOM error would occur, don't increase
    lr = 1e-5
    epochNum = 25
    modelPath = os.path.join("TrainingFilesForUnet", "model.h5") # saves model
        # model.h5: a file saved by the ModelCheckPoint module
    csvPath = os.path.join("TrainingFilesForUnet", "UNETexcelData.csv") # saves data
    
    """Dataset"""
    datasetPath = r"C:\Users\REDACTED NAME\Documents\PortModel\DatasetsForSciExt\DatasetForUnetSegmentation"
    (xTrain, yTrain), (xValid, yValid), (xTest, yTest) = LoadData(datasetPath)
    
    # displays the amount of imgs and masks in each set
    print(f"Train: x = {len(xTrain)}, y = {len(yTrain)}")
    print(f"Validation: x = {len(xValid)}, y = {len(yValid)}")
    print(f"Test: x = {len(xTest)}, y = {len(yTest)}")
    
    # creates datasets
    trainDataset = TfDataset(xTrain, yTrain, batch=batchSize)
    validDataset = TfDataset(xValid, yValid, batch=batchSize)
    
    """Model"""
    model = FullUNET((H, W, 3)) # loads model and provides the correct params
    metrics = [DiceCoef, IoU, Recall(), Precision()] # defines the performance metrics
    model.compile(loss=DiceLoss, optimizer=Adam(lr), metrics=metrics) # compiles model
    
    callbacks = [
        ModelCheckpoint(modelPath, verbose=1, save_best_only=True), # saves the weight files
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1), 
        # for 5 epochs, if val_loss does not decrease, lr will decrease by factor of 0.1
        CSVLogger(csvPath) # records all data while training in csv file
    ]
    
    # training
    model.fit(
        trainDataset,
        epochs=epochNum,
        validation_data=validDataset,
        callbacks=callbacks
    )
# Out:
# 60
# Train: x = 48, y = 48
# Validation: x = 6, y = 6
# Test: x = 6, y = 6
# Epoch 1/25
# 24/24 [==============================] - ETA: 0s - loss: 0.5214 - DiceCoef: 0.4786 - IoU: 0.3159 - recall: 0.7514 - precision: 0.4764
# Epoch 1: val_loss improved from inf to 0.60982, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 183s 8s/step - loss: 0.5214 - DiceCoef: 0.4786 - IoU: 0.3159 - recall: 0.7514 - precision: 0.4764 - val_loss: 0.6098 - val_DiceCoef: 0.3902 - val_IoU: 0.2425 - val_recall: 0.3126 - val_precision: 0.4695 - lr: 1.0000e-05
# Epoch 2/25
# 24/24 [==============================] - ETA: 0s - loss: 0.4405 - DiceCoef: 0.5595 - IoU: 0.3897 - recall: 0.8255 - precision: 0.5143
# Epoch 2: val_loss improved from 0.60982 to 0.60463, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 187s 8s/step - loss: 0.4405 - DiceCoef: 0.5595 - IoU: 0.3897 - recall: 0.8255 - precision: 0.5143 - val_loss: 0.6046 - val_DiceCoef: 0.3954 - val_IoU: 0.2465 - val_recall: 0.7064 - val_precision: 0.4291 - lr: 1.0000e-05
# Epoch 3/25
# 24/24 [==============================] - ETA: 0s - loss: 0.3945 - DiceCoef: 0.6055 - IoU: 0.4358 - recall: 0.8390 - precision: 0.5513
# Epoch 3: val_loss improved from 0.60463 to 0.59466, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 187s 8s/step - loss: 0.3945 - DiceCoef: 0.6055 - IoU: 0.4358 - recall: 0.8390 - precision: 0.5513 - val_loss: 0.5947 - val_DiceCoef: 0.4053 - val_IoU: 0.2544 - val_recall: 0.9544 - val_precision: 0.3740 - lr: 1.0000e-05
# Epoch 4/25
# 24/24 [==============================] - ETA: 0s - loss: 0.3525 - DiceCoef: 0.6475 - IoU: 0.4807 - recall: 0.8460 - precision: 0.6169
# Epoch 4: val_loss improved from 0.59466 to 0.57599, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 188s 8s/step - loss: 0.3525 - DiceCoef: 0.6475 - IoU: 0.4807 - recall: 0.8460 - precision: 0.6169 - val_loss: 0.5760 - val_DiceCoef: 0.4240 - val_IoU: 0.2691 - val_recall: 0.9992 - val_precision: 0.3311 - lr: 1.0000e-05
# Epoch 5/25
# 24/24 [==============================] - ETA: 0s - loss: 0.3131 - DiceCoef: 0.6869 - IoU: 0.5248 - recall: 0.8483 - precision: 0.6872
# Epoch 5: val_loss improved from 0.57599 to 0.55059, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 187s 8s/step - loss: 0.3131 - DiceCoef: 0.6869 - IoU: 0.5248 - recall: 0.8483 - precision: 0.6872 - val_loss: 0.5506 - val_DiceCoef: 0.4494 - val_IoU: 0.2899 - val_recall: 1.0000 - val_precision: 0.3197 - lr: 1.0000e-05
# Epoch 6/25
# 24/24 [==============================] - ETA: 0s - loss: 0.2841 - DiceCoef: 0.7159 - IoU: 0.5584 - recall: 0.8403 - precision: 0.7373
# Epoch 6: val_loss improved from 0.55059 to 0.52763, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 186s 8s/step - loss: 0.2841 - DiceCoef: 0.7159 - IoU: 0.5584 - recall: 0.8403 - precision: 0.7373 - val_loss: 0.5276 - val_DiceCoef: 0.4724 - val_IoU: 0.3093 - val_recall: 1.0000 - val_precision: 0.3194 - lr: 1.0000e-05
# Epoch 7/25
# 24/24 [==============================] - ETA: 0s - loss: 0.2652 - DiceCoef: 0.7348 - IoU: 0.5835 - recall: 0.8538 - precision: 0.7435
# Epoch 7: val_loss improved from 0.52763 to 0.51604, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 189s 8s/step - loss: 0.2652 - DiceCoef: 0.7348 - IoU: 0.5835 - recall: 0.8538 - precision: 0.7435 - val_loss: 0.5160 - val_DiceCoef: 0.4840 - val_IoU: 0.3195 - val_recall: 1.0000 - val_precision: 0.3194 - lr: 1.0000e-05
# Epoch 8/25
# 24/24 [==============================] - ETA: 0s - loss: 0.2503 - DiceCoef: 0.7497 - IoU: 0.6016 - recall: 0.8537 - precision: 0.7578
# Epoch 8: val_loss improved from 0.51604 to 0.51276, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 189s 8s/step - loss: 0.2503 - DiceCoef: 0.7497 - IoU: 0.6016 - recall: 0.8537 - precision: 0.7578 - val_loss: 0.5128 - val_DiceCoef: 0.4872 - val_IoU: 0.3224 - val_recall: 1.0000 - val_precision: 0.3194 - lr: 1.0000e-05
# Epoch 9/25
# 24/24 [==============================] - ETA: 0s - loss: 0.2351 - DiceCoef: 0.7649 - IoU: 0.6210 - recall: 0.8666 - precision: 0.7656
# Epoch 9: val_loss improved from 0.51276 to 0.51223, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 185s 8s/step - loss: 0.2351 - DiceCoef: 0.7649 - IoU: 0.6210 - recall: 0.8666 - precision: 0.7656 - val_loss: 0.5122 - val_DiceCoef: 0.4878 - val_IoU: 0.3231 - val_recall: 1.0000 - val_precision: 0.3194 - lr: 1.0000e-05
# Epoch 10/25
# 24/24 [==============================] - ETA: 0s - loss: 0.2245 - DiceCoef: 0.7755 - IoU: 0.6358 - recall: 0.8690 - precision: 0.7805
# Epoch 10: val_loss improved from 0.51223 to 0.51175, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 185s 8s/step - loss: 0.2245 - DiceCoef: 0.7755 - IoU: 0.6358 - recall: 0.8690 - precision: 0.7805 - val_loss: 0.5117 - val_DiceCoef: 0.4883 - val_IoU: 0.3230 - val_recall: 1.0000 - val_precision: 0.3194 - lr: 1.0000e-05
# Epoch 11/25
# 24/24 [==============================] - ETA: 0s - loss: 0.2170 - DiceCoef: 0.7830 - IoU: 0.6453 - recall: 0.8712 - precision: 0.7818
# Epoch 11: val_loss improved from 0.51175 to 0.51139, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 185s 8s/step - loss: 0.2170 - DiceCoef: 0.7830 - IoU: 0.6453 - recall: 0.8712 - precision: 0.7818 - val_loss: 0.5114 - val_DiceCoef: 0.4886 - val_IoU: 0.3237 - val_recall: 1.0000 - val_precision: 0.3194 - lr: 1.0000e-05
# Epoch 12/25
# 24/24 [==============================] - ETA: 0s - loss: 0.2140 - DiceCoef: 0.7860 - IoU: 0.6502 - recall: 0.8752 - precision: 0.7804
# Epoch 12: val_loss improved from 0.51139 to 0.51086, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 186s 8s/step - loss: 0.2140 - DiceCoef: 0.7860 - IoU: 0.6502 - recall: 0.8752 - precision: 0.7804 - val_loss: 0.5109 - val_DiceCoef: 0.4891 - val_IoU: 0.3241 - val_recall: 1.0000 - val_precision: 0.3194 - lr: 1.0000e-05
# Epoch 13/25
# 24/24 [==============================] - ETA: 0s - loss: 0.2026 - DiceCoef: 0.7974 - IoU: 0.6647 - recall: 0.8861 - precision: 0.7864
# Epoch 13: val_loss improved from 0.51086 to 0.50524, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 186s 8s/step - loss: 0.2026 - DiceCoef: 0.7974 - IoU: 0.6647 - recall: 0.8861 - precision: 0.7864 - val_loss: 0.5052 - val_DiceCoef: 0.4948 - val_IoU: 0.3289 - val_recall: 1.0000 - val_precision: 0.3194 - lr: 1.0000e-05
# Epoch 14/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1957 - DiceCoef: 0.8043 - IoU: 0.6745 - recall: 0.8830 - precision: 0.8001
# Epoch 14: val_loss improved from 0.50524 to 0.46998, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 186s 8s/step - loss: 0.1957 - DiceCoef: 0.8043 - IoU: 0.6745 - recall: 0.8830 - precision: 0.8001 - val_loss: 0.4700 - val_DiceCoef: 0.5300 - val_IoU: 0.3609 - val_recall: 0.9995 - val_precision: 0.3647 - lr: 1.0000e-05
# Epoch 15/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1917 - DiceCoef: 0.8083 - IoU: 0.6791 - recall: 0.8784 - precision: 0.8077
# Epoch 15: val_loss improved from 0.46998 to 0.46117, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 187s 8s/step - loss: 0.1917 - DiceCoef: 0.8083 - IoU: 0.6791 - recall: 0.8784 - precision: 0.8077 - val_loss: 0.4612 - val_DiceCoef: 0.5388 - val_IoU: 0.3689 - val_recall: 0.9979 - val_precision: 0.3713 - lr: 1.0000e-05
# Epoch 16/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1885 - DiceCoef: 0.8115 - IoU: 0.6839 - recall: 0.8820 - precision: 0.8079
# Epoch 16: val_loss did not improve from 0.46117
# 24/24 [==============================] - 186s 8s/step - loss: 0.1885 - DiceCoef: 0.8115 - IoU: 0.6839 - recall: 0.8820 - precision: 0.8079 - val_loss: 0.4630 - val_DiceCoef: 0.5370 - val_IoU: 0.3679 - val_recall: 0.9966 - val_precision: 0.3650 - lr: 1.0000e-05
# Epoch 17/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1860 - DiceCoef: 0.8140 - IoU: 0.6878 - recall: 0.8904 - precision: 0.8039
# Epoch 17: val_loss did not improve from 0.46117
# 24/24 [==============================] - 185s 8s/step - loss: 0.1860 - DiceCoef: 0.8140 - IoU: 0.6878 - recall: 0.8904 - precision: 0.8039 - val_loss: 0.4642 - val_DiceCoef: 0.5358 - val_IoU: 0.3660 - val_recall: 0.9998 - val_precision: 0.3645 - lr: 1.0000e-05
# Epoch 18/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1822 - DiceCoef: 0.8178 - IoU: 0.6931 - recall: 0.8812 - precision: 0.8222
# Epoch 18: val_loss improved from 0.46117 to 0.39783, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 189s 8s/step - loss: 0.1822 - DiceCoef: 0.8178 - IoU: 0.6931 - recall: 0.8812 - precision: 0.8222 - val_loss: 0.3978 - val_DiceCoef: 0.6022 - val_IoU: 0.4311 - val_recall: 0.9715 - val_precision: 0.4460 - lr: 1.0000e-05
# Epoch 19/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1767 - DiceCoef: 0.8233 - IoU: 0.7012 - recall: 0.8866 - precision: 0.8236
# Epoch 19: val_loss improved from 0.39783 to 0.38897, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 192s 8s/step - loss: 0.1767 - DiceCoef: 0.8233 - IoU: 0.7012 - recall: 0.8866 - precision: 0.8236 - val_loss: 0.3890 - val_DiceCoef: 0.6110 - val_IoU: 0.4403 - val_recall: 0.9833 - val_precision: 0.4543 - lr: 1.0000e-05
# Epoch 20/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1760 - DiceCoef: 0.8240 - IoU: 0.7013 - recall: 0.8918 - precision: 0.8155
# Epoch 20: val_loss did not improve from 0.38897
# 24/24 [==============================] - 186s 8s/step - loss: 0.1760 - DiceCoef: 0.8240 - IoU: 0.7013 - recall: 0.8918 - precision: 0.8155 - val_loss: 0.3912 - val_DiceCoef: 0.6088 - val_IoU: 0.4388 - val_recall: 0.9943 - val_precision: 0.4484 - lr: 1.0000e-05
# Epoch 21/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1748 - DiceCoef: 0.8252 - IoU: 0.7036 - recall: 0.8839 - precision: 0.8276
# Epoch 21: val_loss improved from 0.38897 to 0.32191, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 190s 8s/step - loss: 0.1748 - DiceCoef: 0.8252 - IoU: 0.7036 - recall: 0.8839 - precision: 0.8276 - val_loss: 0.3219 - val_DiceCoef: 0.6781 - val_IoU: 0.5140 - val_recall: 0.9629 - val_precision: 0.5569 - lr: 1.0000e-05
# Epoch 22/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1733 - DiceCoef: 0.8267 - IoU: 0.7062 - recall: 0.8929 - precision: 0.8191
# Epoch 22: val_loss improved from 0.32191 to 0.29755, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 191s 8s/step - loss: 0.1733 - DiceCoef: 0.8267 - IoU: 0.7062 - recall: 0.8929 - precision: 0.8191 - val_loss: 0.2975 - val_DiceCoef: 0.7025 - val_IoU: 0.5418 - val_recall: 0.9720 - val_precision: 0.5867 - lr: 1.0000e-05
# Epoch 23/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1638 - DiceCoef: 0.8362 - IoU: 0.7201 - recall: 0.9029 - precision: 0.8280
# Epoch 23: val_loss did not improve from 0.29755
# 24/24 [==============================] - 196s 8s/step - loss: 0.1638 - DiceCoef: 0.8362 - IoU: 0.7201 - recall: 0.9029 - precision: 0.8280 - val_loss: 0.3166 - val_DiceCoef: 0.6834 - val_IoU: 0.5196 - val_recall: 0.9718 - val_precision: 0.5519 - lr: 1.0000e-05
# Epoch 24/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1683 - DiceCoef: 0.8317 - IoU: 0.7131 - recall: 0.8868 - precision: 0.8328
# Epoch 24: val_loss improved from 0.29755 to 0.28957, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 191s 8s/step - loss: 0.1683 - DiceCoef: 0.8317 - IoU: 0.7131 - recall: 0.8868 - precision: 0.8328 - val_loss: 0.2896 - val_DiceCoef: 0.7104 - val_IoU: 0.5512 - val_recall: 0.9218 - val_precision: 0.6042 - lr: 1.0000e-05
# Epoch 25/25
# 24/24 [==============================] - ETA: 0s - loss: 0.1557 - DiceCoef: 0.8443 - IoU: 0.7317 - recall: 0.9036 - precision: 0.8441
# Epoch 25: val_loss improved from 0.28957 to 0.20039, saving model to TrainingFilesForUnet\model.h5
# 24/24 [==============================] - 189s 8s/step - loss: 0.1557 - DiceCoef: 0.8443 - IoU: 0.7317 - recall: 0.9036 - precision: 0.8441 - val_loss: 0.2004 - val_DiceCoef: 0.7996 - val_IoU: 0.6669 - val_recall: 0.8894 - val_precision: 0.7822 - lr: 1.0000e-05
